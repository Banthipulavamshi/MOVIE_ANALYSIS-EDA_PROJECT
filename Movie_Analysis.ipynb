# %%
#Libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#dataset

data = pd.read_csv(r"C:\Users\vamsh\Downloads\IMDb_Dataset.csv")

# %%
data
# Out:
#                                              Title  IMDb Rating  Year  \
# 0                                        Gladiator          8.5  2000
# 1    Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2             Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                             Inglourious Basterds          8.4  2009
# 4                                      Borderlands          7.1  2024
# ..                                             ...          ...   ...
# 395                            Mother of the Bride          4.8  2024
# 396                        Beetlejuice Beetlejuice          7.1  2024
# 397                                The Idea of You          6.4  2024
# 398                                             IF          6.7  2024
# 399                                   The Fall Guy          7.1  2024
#
#     Certificates      Genre               Director  \
# 0              R     Action           Ridley Scott
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               400 non-null    object
#  1   IMDb Rating         400 non-null    float64
#  2   Year                400 non-null    int64
#  3   Certificates        400 non-null    object
#  4   Genre               400 non-null    object
#  5   Director            400 non-null    object
#  6   Star Cast           400 non-null    object
#  7   MetaScore           400 non-null    float64
#  8   Duration (minutes)  400 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 28.3+ KB

# %%
data.shape
# Out:
# (400, 9)

# %%
data.head()
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 3            R  Adventure      Quentin Tarantino
# 4            R     Action               Eli Roth
#
#                                    Star Cast  MetaScore  Duration (minutes)
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# ...

# %%
data.tail()
# Out:
#                        Title  IMDb Rating  Year Certificates      Genre  \
# 395      Mother of the Bride          4.8  2024        TV-PG     Comedy
# 396  Beetlejuice Beetlejuice          7.1  2024            R     Comedy
# 397          The Idea of You          6.4  2024            R     Comedy
# 398                       IF          6.7  2024           PG  Animation
# 399             The Fall Guy          7.1  2024        PG-13     Action
#
#               Director                                     Star Cast  \
# 395        Mark Waters  Brooke ShieldsMiranda CosgroveBenjamin Bratt
# 396         Tim Burton    Alfred GoughMiles MillarSeth Grahame-Smith
# 397  Michael Showalter     Anne HathawayNicholas GalitzineElla Rubin
# 398     John Krasinski     Cailey FlemingRyan ReynoldsJohn Krasinski
# 399       David Leitch   Ryan GoslingEmily BluntAaron Taylor-Johnson
#
#      MetaScore  Duration (minutes)
# 395       39.0                88.0
# 396       66.9               116.3
# ...

# %%
data.isnull()
# Out:
#      Title  IMDb Rating   Year  Certificates  Genre  Director  Star Cast  \
# 0    False        False  False         False  False     False      False
# 1    False        False  False         False  False     False      False
# 2    False        False  False         False  False     False      False
# 3    False        False  False         False  False     False      False
# 4    False        False  False         False  False     False      False
# ..     ...          ...    ...           ...    ...       ...        ...
# 395  False        False  False         False  False     False      False
# 396  False        False  False         False  False     False      False
# 397  False        False  False         False  False     False      False
# 398  False        False  False         False  False     False      False
# 399  False        False  False         False  False     False      False
#
#      MetaScore  Duration (minutes)
# 0        False               False
# ...

# %%
data.isnull().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
data[data.index == 250]
# Out:
#              Title  IMDb Rating  Year Certificates      Genre     Director  \
# 250  The Lion King          6.8  2019           PG  Animation  Jon Favreau
#
#                                       Star Cast  MetaScore  Duration (minutes)
# 250  Jeff NathansonIrene MecchiJonathan Roberts       55.0               118.0

# %%
#Isolating tweo or more rows using []
#Similarly, two or more rows can be returned using the .isin() method instead of a == operator.
data[data.index.isin(range(20,51))]
# Out:
#                                                 Title  IMDb Rating  Year  \
# 20                                    Kung Fu Panda 4          6.3  2024
# 21                         Mad Max Beyond Thunderdome          6.2  1985
# 22                                     Manjummel Boys          8.4  2024
# 23                                       Golden Kamuy          6.4  2024
# 24                                       Interstellar          8.7  2014
# 25                                 Planet of the Apes          8.0  1968
# 26                                             Barbie          6.8  2023
# 27                                           Twisters          7.1  2024
# 28  The Hunger Games: The Ballad of Songbirds & Sn...          6.7  2023
# 29                                       Inside Out 2          7.1  2024
# 30                              Bad Boys: Ride or Die          7.1  2024
# 31                        Mad Max 2: The Road Warrior          7.6  1981
# ...

# %%
data.shape[0]
# Out:
# 400

# %%
data.shape[1]
# Out:
# 9

# %%
data.describe()
# Out:
#        IMDb Rating         Year   MetaScore  Duration (minutes)
# count   400.000000   400.000000  400.000000          400.000000
# mean      7.110250  2015.150000   66.898750          116.334750
# std       0.932251    13.470194   15.312006           21.369757
# min       3.900000  1939.000000   26.000000           80.000000
# 25%       6.700000  2010.750000   57.750000          101.000000
# 50%       7.100000  2023.000000   66.900000          116.000000
# 75%       7.700000  2024.000000   77.000000          124.000000
# max       9.200000  2025.000000  100.000000          206.000000

# %%
data.isnull().head()
# Out:
#    Title  IMDb Rating   Year  Certificates  Genre  Director  Star Cast  \
# 0  False        False  False         False  False     False      False
# 1  False        False  False         False  False     False      False
# 2  False        False  False         False  False     False      False
# 3  False        False  False         False  False     False      False
# 4  False        False  False         False  False     False      False
#
#    MetaScore  Duration (minutes)
# 0      False               False
# 1      False               False
# 2      False               False
# 3      False               False
# 4      False               False

# %%
data['IMDb Rating'].value_counts()
# Out:
# IMDb Rating
# 7.1    59
# 7.0    24
# 7.6    21
# 6.7    18
# 7.2    16
# 6.8    16
# 7.4    14
# 8.0    13
# 7.9    13
# 7.5    13
# 8.1    12
# 8.2    12
# 7.3    11
# 6.5    11
# 5.6    10
# 6.2    10
# 5.7    10
# 8.4    10
# 8.6     9
# 6.3     9
# 7.7     8
# 7.8     8
# 8.5     8
# 6.1     6
# 5.8     5
# 5.9     5
# 6.9     5
# 6.0     5
# 8.7     4
# 5.5     4
# 6.4     4
# 5.0     4
# 3.9     3
# 8.3     3
# 5.2     3
# 5.3     2
# 9.0     2
# 8.8     2
# 8.9     2
# 6.6     1
# 4.6     1
# 9.2     1
# 4.9     1
# 4.4     1
# 4.8     1
# Name: count, dtype: int64

# %%
data['Star Cast'].value_counts()
# Out:
# Star Cast
# Gil KenanJason ReitmanIvan Reitman             7
# Brittany HowardWill ForteJon Heder             4
# Hayao Miyazaki                                 4
# Will SmithMartin LawrenceVanessa Hudgens       4
# Jonathan AibelGlenn BergerDarren Lemke         4
#                                               ..
# Quentin TarantinoRoger Avary                   1
# Tom CruiseHayley AtwellVing Rhames             1
# Jodie ComerAustin ButlerTom Hardy              1
# Mario PuzoFrancis Ford Coppola                 1
# Ryan GoslingEmily BluntAaron Taylor-Johnson    1
# Name: count, Length: 247, dtype: int64

# %%
top_10_IMDb_Rating= data.nlargest(10, 'IMDb Rating')
print("\nTop 10 IMDb Rating:")
print(top_10_IMDb_Rating)
# Out:
# Top 10 IMDb Rating:
#                                                  Title  IMDb Rating  Year  \
# 137                                      The Godfather          9.2  1972
# 106                                       12 Angry Men          9.0  1957
# 130                                    The Dark Knight          9.0  2008
# 15   The Lord of the Rings: The Fellowship of the Ring          8.9  2001
# 132                                       Pulp Fiction          8.9  1994
# 14                                           Inception          8.8  2010
# 221                                          Inception          8.8  2010
# 24                                        Interstellar          8.7  2014
# 125                                         Goodfellas          8.7  1990
# 211                                         The Matrix          8.7  1999
#
#     Certificates      Genre              Director  \
# 137            R      Crime  Francis Ford Coppola
# ...

# %%
data.iloc[10:51]
# Out:
#                                                 Title  IMDb Rating  Year  \
# 10                                   The Hunger Games          7.2  2012
# 11             Rebel Moon - Part One: A Child of Fire          5.6  2023
# 12              Harry Potter and the Sorcerer's Stone          7.6  2001
# 13                                              Wonka          7.0  2023
# 14                                          Inception          8.8  2010
# 15  The Lord of the Rings: The Fellowship of the Ring          8.9  2001
# 16                                            Twister          6.5  1996
# 17                                             Damsel          6.1  2024
# 18                                               Dune          6.3  1984
# 19                                    Arthur the King          7.0  2024
# 20                                    Kung Fu Panda 4          6.3  2024
# 21                         Mad Max Beyond Thunderdome          6.2  1985
# ...

# %%
plt.figsize = (60,60)
sns.histplot(data ,x="IMDb Rating",y="Genre")
# Out:
# <Axes: xlabel='IMDb Rating', ylabel='Genre'>

# %%
plt.figsize = (100,100)
sns.displot(data, y="Genre",x="Year")

# %%
plt.figsize = (10,20)
sns.relplot(data ,y="Genre", x="Duration (minutes)")

# %%
plt.figsize = (100,100)
sns.barplot(data , y="Year", x="MetaScore")
# Out:
# <Axes: xlabel='MetaScore', ylabel='Year'>

# %%
sns.lmplot(y="Year", x="Duration (minutes)", data=data)

# %%
plt.figsize = (150,150)
sns.catplot(data=data, x="IMDb Rating", y="Year")

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='Duration (minutes)', hue='Title', bins=10, kde=True, multiple="stack")

# Add labels
plt.xlabel('Duration (minutes)')
plt.ylabel('Title')

# Show the plot
plt.show()
# Out:
# C:\Users\vamsh\anaconda3\Lib\site-packages\seaborn\distributions.py:267: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   baselines[cols] = curves[cols].shift(1, axis=1).fillna(0)

# %%
status_counts = data['Genre'].value_counts()
plt.figure(figsize=(10, 10))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140)
plt.show()

# %%
sns.boxplot(x="Certificates", y="IMDb Rating", data=data)

plt.xlabel("Certificates")
plt.ylabel("IMDb Rating")
plt.show()

# %%
sns.violinplot(x="Genre", y="Year", data=data)

plt.xlabel("Genre")
plt.ylabel("Year")
plt.show()

# %%
corr_matrix = data.select_dtypes(include=['number']).corr()

# Create a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True, cmap='YlOrBr', linewidths=0.5)

plt.show()

# %%
sns.pairplot(data.select_dtypes(include=['number']))

plt.show()
